# %% [markdown]
# 1. [Best strategies](#strategies)
#     1. [Binance historical data (08/17/2017 - 12/25/2020)](#alltime)
#     2. [No bullrun phase (03/01/2018 - 11/15/2020)](#nobullrun)
#     3. [Save strategies](#save)

# %% [markdown]
# # Best strategies <a name="strategies"></a>

# %%
import pandas as pd
import os

# %% [markdown]
# We will now collect all the results into one dataframe to easily compare the strategies.

# %%
df = pd.DataFrame()

for result in os.listdir("/home/trading/result"):
    result = '/home/trading/result/' + result
    temp = pd.read_csv(result)
    df = pd.concat([df, temp])

# %% [markdown]
# To evaluate our strategy we will use Van's System Quality Number (SQN) which is one of the many indicators designed to assist traders in determining the strengths, desirability, quality etc of a trading system. The idea behind SQN is to use it to find good quality strategies. And a good quality strategy is seen as one that is both tradable (is it easy, or is it difficult to trade) and efficient (does it make good money when a money management strategy is applied).
#
# The following values suggest the following “qualities” :
#
# * 1.6 - 1.9 Below average
# * 2.0 - 2.4 Average
# * 2.5 - 2.9 Good
# * 3.0 - 5.0 Excellent
# * 5.1 - 6.9 Superb
# * 7.0 - Holy Grail
#
# The formula :
# * SquareRoot(NumberTrades) * Average(TradesProfit) / StdDev(TradesProfit)
#
# The sqn value should be deemed reliable when the number of trades **>= 30**

# %% [markdown]
# Therefore we will remove all line with a total trades less than 30.

# %%
df_result = df.loc[(df['Total win'] + df['Total loss']) >= 30]
df_result
# Out:
#        Pair Timeframe       Start         End        Strategy  Period  \
# 5   ETHUSDT        2h  2020-01-01  2021-10-04  stoch_macd_rsi       6
# 6   ETHUSDT        2h  2020-01-01  2021-10-04  stoch_macd_rsi       7
# 7   ETHUSDT        2h  2020-01-01  2021-10-04  stoch_macd_rsi       8
# 8   ETHUSDT        2h  2020-01-01  2021-10-04  stoch_macd_rsi       9
# 9   ETHUSDT        2h  2020-01-01  2021-10-04  stoch_macd_rsi      10
# ..      ...       ...         ...         ...             ...     ...
# 24  ETHUSDT     15min  2020-01-01  2021-10-04  stoch_macd_rsi      25
# 25  ETHUSDT     15min  2020-01-01  2021-10-04  stoch_macd_rsi      26
# 26  ETHUSDT     15min  2020-01-01  2021-10-04  stoch_macd_rsi      27
# 27  ETHUSDT     15min  2020-01-01  2021-10-04  stoch_macd_rsi      28
# 28  ETHUSDT     15min  2020-01-01  2021-10-04  stoch_macd_rsi      29
#
#      Final value       %  Total win  Total loss   SQN
# 5   1.039338e+07   3.934         15          16  0.74
# 6   1.002295e+07   0.229         17          22  0.04
# 7   9.659225e+06  -3.408         21          28 -0.51
# 8   9.945378e+06  -0.546         25          28 -0.07
# 9   9.729402e+06  -2.706         26          33 -0.36
# ..           ...     ...        ...         ...   ...
# 24  6.221161e+06 -37.788        877         975 -1.58
# 25  6.425020e+06 -35.750        907        1015 -1.42
# 26  5.927595e+06 -40.724        926        1044 -1.66
# 27  5.606673e+06 -43.933        943        1074 -1.83
# 28  5.242036e+06 -47.580        958        1099 -2.02
#
# [142 rows x 11 columns]

# %% [markdown]
# And then sort the dataframe according their rank.

# %%
df_alltime = df_result.sort_values('SQN', ascending=False)
df_alltime['Rank'] = df_alltime['SQN'].rank(method='min', ascending=False)

# %% [markdown]
# ## Binance historical data (08/17/2017 - 12/25/2020) <a name="alltime"></a>

# %%
topSQN = df_alltime.head(10)

topSqnSqn = list(topSQN['SQN'])
topSqnProfit = list(round(topSQN['%'],3))
topSqnWin = list(topSQN['Total win'])
topSqnLoss = list(topSQN['Total loss'])
index = list(topSQN['Rank'])

topSQN
# Out:
#        Pair Timeframe       Start         End        Strategy  Period  \
# 13  ETHUSDT        4h  2020-01-01  2021-10-04  stoch_macd_rsi      14
# 12  ETHUSDT        4h  2020-01-01  2021-10-04  stoch_macd_rsi      13
# 10  ETHUSDT        4h  2020-01-01  2021-10-04  stoch_macd_rsi      11
# 9   ETHUSDT        4h  2020-01-01  2021-10-04  stoch_macd_rsi      10
# 11  ETHUSDT        4h  2020-01-01  2021-10-04  stoch_macd_rsi      12
# 13  ETHUSDT        6h  2020-01-01  2021-10-04  stoch_macd_rsi      14
# 14  ETHUSDT        4h  2020-01-01  2021-10-04  stoch_macd_rsi      15
# 8   ETHUSDT        4h  2020-01-01  2021-10-04  stoch_macd_rsi       9
# 23  ETHUSDT        4h  2020-01-01  2021-10-04  stoch_macd_rsi      24
# 28  ETHUSDT        4h  2020-01-01  2021-10-04  stoch_macd_rsi      29
#
#      Final value       %  Total win  Total loss   SQN  Rank
# 13  1.636557e+07  63.656         26          15  3.46   1.0
# 12  1.568280e+07  56.828         24          15  3.18   2.0
# 10  1.490712e+07  49.071         21          15  2.93   3.0
# 9   1.441055e+07  44.105         22          12  2.87   4.0
# 11  1.453450e+07  45.345         22          14  2.80   5.0
# 13  1.294383e+07  29.438         21           9  2.49   6.0
# 14  1.467230e+07  46.723         26          23  2.48   7.0
# 8   1.353489e+07  35.349         18          12  2.38   8.0
# 23  1.719147e+07  71.915         45          31  2.37   9.0
# 28  1.785386e+07  78.539         49          38  2.30  10.0

# %% [markdown]
# In our top 10 best strategies return we have 1 excellent System Quality Number, all the rests are good.
#
# We have mainly BTCUSDT pair traded however, the only 3 strategy in that top10 that traded ETHUSDT are listed in the top 5 best sqn (and even top 1 with an excellent sqn > 3).
#
# Surprisingly, our SMA strategy succedeed far better than our RSI. This might be explained by the fact that the RSI has taken less than 30 positions on "high" timeframe (> 4h).
#
# The few positions taken are not even sucessfull for the majority :

# %%
tfhigh_rsi = df_alltime.loc[(df_alltime['Strategy'] == 'RSI') & ((df_alltime['Timeframe'] == '6h') | (df_alltime['Timeframe'] == '8h') | (df_alltime['Timeframe'] == '12h') | (df_alltime['Timeframe'] == '1w'))]

tfhigh_rsi
# Out:
# Empty DataFrame
# Columns: [Pair, Timeframe, Start, End, Strategy, Period, Final value, %, Total win, Total loss, SQN, Rank]
# Index: []

# %% [markdown]
# Back to our top 10, we notice that we have many values of period near 10 which means we might have unfortunately missed some good strategy using period < 10. This is something to take into account next time we run our code.

# %% [markdown]
# We can also notice that a better sqn doesn't necessary mean better profit as the next charts can illustrates :

# %%
topSqnBars = pd.DataFrame({'sqn': topSqnSqn, 'profit %': topSqnProfit}, index=index)
topSqnBars.index.name = 'strategy rank'
# topSqnBarsSplit = topSqnBars.plot.bar(rot=0, subplots=True)
# topSqnBarsSplit[1].legend(loc=2);

# %% [markdown]
# What's interesting is to see that all our top strategies made at least 2x more negatives trades than positives, nevertheless the final results remains positive. This mean we have a good ratio per trade, in other words for 1 winning trade we can expect to lose *x* times before having a final outcome of 0 since our one profit was either too big, or our losses too small.

# %%
topSqnBars2 = pd.DataFrame({'win': topSqnWin, 'loss': topSqnLoss}, index=index)
topSqnBars2.index.name = 'strategy rank'
# topSqnBars2.plot.bar(rot=0);

# %% [markdown]
# This really good ratio per trade may be the result of the bullrun that occured in 2017 and end November/start of December 2020 which might have results in big gains.
#
# This assumptions can be backed with the fact that all our top strategies were applied to our historical data that includes the bullrun period (08/17/2017 - 12/25/2020).

# %% [markdown]
# Let's see and compare with what we will get if we remove the bullrun period.

# %% [markdown]
# ## No bullrun phase (03/01/2018 - 11/15/2020) <a name="nobullrun"></a>

# %%
df_nobullrun = df_result.loc[df_result['Start'] == '2018-03-01'].sort_values('SQN', ascending=False)
df_nobullrun['Rank'] = df_nobullrun['SQN'].rank(method='min', ascending=False)

topNoBullrun = df_nobullrun.head(10)

# %%
def sameETHTop(s):
    """
    Display in a different background color the strategies on ETHUSDT pair already present in our previous all time top 10.
    """
    if (s['Pair'] == 'ETHUSDT' and s['Timeframe'] == '6h' and s['Strategy'] == 'SMA') and (s['Period'] == 11 or s['Period'] == 12 or s['Period'] == 10):
        return ['background-color: green']*s.size
    else:
        return ['background-color: default']*s.size
        
topNoBullrun.reset_index(drop=True).style.apply(sameETHTop, axis=1)
# Out:
# <style  type="text/css" >
# #T_45cb8f42_5001_11eb_9712_106530f419farow0_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col8,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col9,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col10,#T_45cb8f42_5001_11eb_9712_106530f419farow0_col11,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col8,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col9,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col10,#T_45cb8f42_5001_11eb_9712_106530f419farow1_col11,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col8,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col9,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col10,#T_45cb8f42_5001_11eb_9712_106530f419farow3_col11,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col8,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col9,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col10,#T_45cb8f42_5001_11eb_9712_106530f419farow5_col11,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col8,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col9,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col10,#T_45cb8f42_5001_11eb_9712_106530f419farow6_col11,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col8,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col9,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col10,#T_45cb8f42_5001_11eb_9712_106530f419farow8_col11,#T_45cb8f42_5001_11eb_9712_106530f419farow9_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow9_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow9_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow9_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow9_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow9_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow9_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow9_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow9_col8,#T_45cb8f42_5001_11 ...
#             background-color:  default;
#         }#T_45cb8f42_5001_11eb_9712_106530f419farow2_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col8,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col9,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col10,#T_45cb8f42_5001_11eb_9712_106530f419farow2_col11,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col8,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col9,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col10,#T_45cb8f42_5001_11eb_9712_106530f419farow4_col11,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col0,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col1,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col2,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col3,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col4,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col5,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col6,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col7,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col8,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col9,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col10,#T_45cb8f42_5001_11eb_9712_106530f419farow7_col11{
#             background-color:  green;
#         }</style><table id="T_45cb8f42_5001_11eb_9712_106530f419fa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pair</th>        <th class="col_heading level0 col1" >Timeframe</th>        <th class="col_heading level0 col2" >Start</th>        <th class="col_heading level0 col3" >End</th>        <th class="col_heading level0 col4" >Strategy</th>        <th class="col_heading level0 col5" >Period</th>        <th class="col_heading level0 col6" >Final value</th>        <th class="col_heading level0 col7" >%</th>        <th class="col_heading level0 col8" >Total win</th>        <th class="col_heading level0 col9" >Total loss</th>        <th class="col_heading level0 col10" >SQN</th>        <th class="col_heading level0 col11" >Rank</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45cb8f42_5001_11eb_9712_106530f419falevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_45cb8f42_5001_11eb_9712_106530f419farow0_col0" class="data row0 col0" >ETHUSDT</td>
#                         <td id="T_45cb8f42_5001_11eb_9712_106530f419farow0_col1" class="data row0 col1" >4h</td>
#                         <td id="T_45cb8f42_5001_11eb_9712_106530f419farow0_col2" class="data row0 col2" >2018-03-01</td>
#                         <td id="T_45cb8f42_5001_11eb_9712_106530f419farow0_col3" class="data row0 col3" >2020-11-15</td>
#                         <td id="T_45cb8f42_5001_11eb_9712_106530f419farow0_col4" class="data row0 col4" >SMA</td>
#                         <td id="T_45cb8f42_5001_11eb_9712_106530f419farow0_col5" class="data row0 col5" >17</td>
#                         <td id="T_45cb8f42_5001_11eb_9712_106530f419farow0_col6" class="data row0 col6" >12711.644000</td>
#                         <td id="T_45cb8f42_5001_11eb_9712_106530f419farow0_col7" class="data row0 col7" >27.116000</td>
#                         <td id="T_45cb8f42_5001_11eb_9712_106530f419farow0_

# %% [markdown]
# It looks like in time of range our strategies were more successfull on the ETHUSDT pair using SMA indicator. We notice that our previous 3 strategy on ETHUSDT that worked particularly fine on the all time period are also present in that new top 10 (at the index 2, 4 and 7).
#
# This is reassuring as we don't always know if we are in a trend or range period, but we now know that some of our strategies works fine with both. However, the sqn was not as good as before during this period, actually it is even on average (2.0 - 2.4).
#
# What we can also notice is that the timeframes resulting in better performance are lower than if we include the bullrun period (many 4h and no 8/12h), and conversely for the SMA period (only 3 lower or equal to 12 versus 7).

# %% [markdown]
# Let's just have a quicklook on the rank of the BTCUSDT pair that were in our all time top 10.

# %%
df_nobullrun.loc[(df_nobullrun['Pair'] == 'BTCUSDT') & (df_nobullrun['Timeframe'] == '12h') & (df_nobullrun['Strategy'] == 'SMA') & (df_nobullrun['Period'] == 10)]
# Out:
# Empty DataFrame
# Columns: [Pair, Timeframe, Start, End, Strategy, Period, Final value, %, Total win, Total loss, SQN, Rank]
# Index: []

# %%
df_nobullrun.loc[(df_nobullrun['Pair'] == 'BTCUSDT') & (df_nobullrun['Timeframe'] == '12h') & (df_nobullrun['Strategy'] == 'SMA') & (df_nobullrun['Period'] == 11)]
# Out:
# Empty DataFrame
# Columns: [Pair, Timeframe, Start, End, Strategy, Period, Final value, %, Total win, Total loss, SQN, Rank]
# Index: []

# %%
df_nobullrun.loc[(df_nobullrun['Pair'] == 'BTCUSDT') & (df_nobullrun['Timeframe'] == '8h') & (df_nobullrun['Strategy'] == 'SMA') & (df_nobullrun['Period'] == 22)]
# Out:
# Empty DataFrame
# Columns: [Pair, Timeframe, Start, End, Strategy, Period, Final value, %, Total win, Total loss, SQN, Rank]
# Index: []

# %%
df_nobullrun.loc[(df_nobullrun['Pair'] == 'BTCUSDT') & (df_nobullrun['Timeframe'] == '4h') & (df_nobullrun['Strategy'] == 'SMA') & (df_nobullrun['Period'] == 18)]
# Out:
# Empty DataFrame
# Columns: [Pair, Timeframe, Start, End, Strategy, Period, Final value, %, Total win, Total loss, SQN, Rank]
# Index: []

# %%
df_nobullrun.loc[(df_nobullrun['Pair'] == 'BTCUSDT') & (df_nobullrun['Timeframe'] == '6h') & (df_nobullrun['Strategy'] == 'SMA') & (df_nobullrun['Period'] == 13)]
# Out:
#       Pair Timeframe       Start         End Strategy  Period  Final value  \
# 3  BTCUSDT        6h  2018-03-01  2020-11-15      SMA      13    11576.825
#
#         %  Total win  Total loss   SQN  Rank
# 3  15.809         76         206  1.79  46.0

# %%
df_nobullrun.loc[(df_nobullrun['Pair'] == 'BTCUSDT') & (df_nobullrun['Timeframe'] == '12h') & (df_nobullrun['Strategy'] == 'SMA') & (df_nobullrun['Period'] == 12)]
# Out:
#       Pair Timeframe       Start         End Strategy  Period  Final value  \
# 2  BTCUSDT       12h  2018-03-01  2020-11-15      SMA      12    11601.523
#
#         %  Total win  Total loss   SQN  Rank
# 2  15.738         38          97  1.74  54.0

# %%
df_nobullrun.loc[(df_nobullrun['Pair'] == 'BTCUSDT') & (df_nobullrun['Timeframe'] == '8h') & (df_nobullrun['Strategy'] == 'SMA') & (df_nobullrun['Period'] == 12)]
# Out:
#       Pair Timeframe       Start         End Strategy  Period  Final value  \
# 2  BTCUSDT        8h  2018-03-01  2020-11-15      SMA      12    11437.731
#
#         %  Total win  Total loss   SQN  Rank
# 2  13.836         59         156  1.61  92.0

# %% [markdown]
# It doesn't look like they performed well. Even though their profits are positive their sqn are below average **so we prefer trading the BTCUSDT pair during upward trend and ETHUSDT in everytime.**

# %% [markdown]
# ## Save strategies <a name="save"></a>

# %% [markdown]
# Now let's save our topSQN pandas dataframe to a JSON file so that we may reuse these strategies.

# %%
topSQN.to_json(r'top10sqn.json', orient='records')
