# %%
import pandas as pd
import os
pd.options.display.float_format = '{:,.4f}'.format

# %%
file = 'buy_hold.csv'
df = pd.read_csv(file)
df = df.sort_values("ROI %", ascending=False)

df['Initial value'] = df['Initial value'].astype(float)
df['Final value'] = df['Final value'].astype(float)
df['Diff'] = df['Final value'] - df['Initial value']
df
# Out:
#          Symbol  Start   End  Strategy  Initial value  Final value   ROI %  \
# AVAXUSDT     1d   2021  2021  buy_hold    10,000.0000 196,764.0000 18.6760
# CHZUSDT      1d   2021  2021  buy_hold    10,000.0000 129,329.0000 11.9330
# HNTUSDT      1d   2021  2021  buy_hold    10,000.0000 127,309.0000 11.7310
# IOTAUSDT     1d   2021  2021  buy_hold    10,000.0000  42,987.0000  3.2990
# ORNUSDT      1d   2021  2021  buy_hold    10,000.0000  39,881.0000  2.9880
# ETHUSDT      1d   2021  2021  buy_hold    10,000.0000  38,534.0000  2.8530
# FILUSDT      1d   2021  2021  buy_hold    10,000.0000  28,199.0000  1.8200
# LINKUSDT     1d   2021  2021  buy_hold    10,000.0000  19,473.0000  0.9470
# ARUSDT       1d   2021  2021  buy_hold    10,000.0000  16,148.0000  0.6150
# BTCUSDT      1d   2021  2021  buy_hold    10,000.0000  10,000.0000  0.0000
#
#                  Diff
# AVAXUSDT 186,764.0000
# CHZUSDT  119,329.0000
# HNTUSDT  117,309.0000
# IOTAUSDT  32,987.0000
# ORNUSDT   29,881.0000
# ETHUSDT   28,534.0000
# FILUSDT   18,199.0000
# LINKUSDT   9,473.0000
# ARUSDT     6,148.0000
# BTCUSDT        0.0000
